# %% [markdown]
# #1. Buat variabel skalar x dan simpan suatu nilai skalar

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 60
x

# %%
#tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 6
y

# %%
#tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
#jumlahkan x + y
x + y
# Out:
# 66

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.6

# %%
#jumlahkan x_float dengan y
x_float + y
# Out:
# 6.6

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# # 2. Lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_tf = 60

# %%
#tampilkan tipe data dari x
x_tf = tf.Variable(60, dtype=tf.int32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=60>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_tf = 6

# %%
#tampilkan tipe data dari y
y_tf = tf.Variable(6, dtype=tf.int32)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=6>

# %%
#jumlahkan x + y
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=66>

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
tf_float = 0.6

# %%
#tampilkan tipe data dari x_float
tf_float = tf.Variable(0.6, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=0.60009765625>

# %% [markdown]
# # 3. Lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch as pt

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = 60
x_pt
# Out:
# 60

# %%
# tampilkan tipe data dari x
x_pt = pt.tensor(60, dtype=pt.int32)
x_pt
# Out:
# tensor(60, dtype=torch.int32)

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_pt = 6
y_pt
# Out:
# 6

# %%
# tampilkan tipe data dari y
y_pt = pt.tensor(6, dtype=pt.int32)
y_pt
# Out:
# tensor(6, dtype=torch.int32)

# %%
# jumlahkan x+y
x_pt + y_pt
# Out:
# tensor(66, dtype=torch.int32)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
xpt_float = 0.6

# %%
# jumlahkan x_float dengan y
ptfloat_sum = pt.add(xpt_float, y_pt)
ptfloat_sum
# Out:
# tensor(6.6000)
